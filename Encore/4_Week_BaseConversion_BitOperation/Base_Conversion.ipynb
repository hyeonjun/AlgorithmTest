# %% [markdown]
# # 진법 변환
#
# ### - 문제설명
#
# B진법 수 N이 주어진다. 이 수를 10진법으로 바꿔 출력하는 프로그램을 작성하시오.
#
# 10진법을 넘어가는 진법은 숫자로 표시할 수 없는 자리가 있다. 이런 경우에는 다음과 같이 알파벳 대문자를 사용한다.
#
# A: 10, B: 11, ..., F: 15, ..., Y: 34, Z: 35
#
#
# ### - 입력
#
# 첫째 줄에 N과 B가 주어진다. (2 ≤ B ≤ 36)
#
# B진법 수 N을 10진법으로 바꾸면, 항상 10억보다 작거나 같다.
#
# ### - 출력
#
# 첫째 줄에 B진법 수 N을 10진법으로 출력한다.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 풀이
#
# 처음에는 1~Z까지 '0':0, '1':1, ...'Y':34,'Z':35 이렇게 딕셔너리로 만들어서 풀어볼까 했는데 너무 귀찮다... 그래서 생각해낸 것이 아스키코드값인데, Z의 값을 보면 90이므로 55를 빼주면 될 것 같다고 생각했다.
#
# 그런데 여기서 문제는 받는 N 안에는 문자만 있는 것이 아닌 숫자도 있다는 것이다. 그래서 이를 어떻게 처리할지 생각하다가 파이썬에서 제공하는 isdigit() 이라는 메서드를 사용하여 해당 문자열이 숫자인지 판단하여 True, False를 반환해준다. 이를 활용하여 각 자리의 값을 구해서 진법 계산해주면 될 것 같다.

# %%
'1'.isdigit()
# Out:
# True

# %%
ord('Z')
# Out:
# 90

# %%
n, b = input().split()
b = int(b)
answer = 0
for i, v in enumerate(n[::-1]):
    v = int(v) if v.isdigit() else ord(v)-55
    answer += (v * (b ** i))
print(answer)
# Out:
# ZZZZZ 36
# 60466175

# %% [markdown]
# ![image.png](data:image/png;base64,...)
