# %% [markdown]
# # 정수 삼각형
#
# ### - 문제 설명
#
# ![image.png](data:image/png;base64,...)
#
# 위와 같은 삼각형의 꼭대기에서 바닥까지 이어지는 경로 중, 거쳐간 숫자의 합이 가장 큰 경우를 찾아보려고 합니다. 아래 칸으로 이동할 때는 대각선 방향으로 한 칸 오른쪽 또는 왼쪽으로만 이동 가능합니다. 예를 들어 3에서는 그 아래칸의 8 또는 1로만 이동이 가능합니다.
#
# 삼각형의 정보가 담긴 배열 triangle이 매개변수로 주어질 때, 거쳐간 숫자의 최댓값을 return 하도록 solution 함수를 완성하세요.
#
# ### - 제한사항
#
# * 삼각형의 높이는 1 이상 500 이하입니다.
# * 삼각형을 이루고 있는 숫자는 0 이상 9,999 이하의 정수입니다.
#
# ### - 입출력 예
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 풀이
#
# 각 줄의 첫 번째 인덱스의 경우 이전 줄의 첫 번째 인덱스에서만 올 수 있고,
#
# 각 줄의 마지막 인덱스의 경우 이전 줄의 마지막 인덱스에서만 올 수있다.
#
# 그 사이의 인덱스의 경우 이전 줄의 한 칸 오른쪽 또는 왼쪽에서 올 수  있으므로
#
# max(이전 줄의 오른쪽, 이전 줄의 왼쪽) 이 된다.
#
# 7
#
# 3 8
#
# 8 1 0
#
# 2 7 4 4
#
# 4 5 2 6 5
#
#
# j == 0 : dp[i][j] += dp[i-1][j] # 각 줄의 첫 번째 인덱스
#
# j == i : dp[i][j] += dp[i-1][j-1] # 각 줄의 마지막 인덱스
#
# else : dp[i][j] += max(dp[i-1][j], dp[i-1][j-1] # 그 사이 인덱스들

# %%
def solution(triangle):
    for i in range(1, len(triangle)):
        for j in range(len(triangle[i])):
            if j == 0: triangle[i][j] += triangle[i-1][j] # 첫 번째 인덱스
            elif j == i: triangle[i][j] += triangle[i-1][j-1] # 마지막 인덱스
            else:
                triangle[i][j] += max(triangle[i-1][j], triangle[i-1][j-1])
    return max(triangle[-1])

# %%
print(solution([[7], [3, 8], [8, 1, 0], [2, 7, 4, 4], [4, 5, 2, 6, 5]]))
# Out:
# 30

# %% [markdown]
# ![image.png](data:image/png;base64,...)
